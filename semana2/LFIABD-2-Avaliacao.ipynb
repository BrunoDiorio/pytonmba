# %% [markdown]
# # <font color="red"> MBA em IA e Big Data</font>
# ## <span style="color:red">Linguagens e Ferramentas para Inteligência Artificial e Big Data (Python e SQL)</span>
#
# ### <span style="color:darkred">Semana 2</span>
#
# ## Avaliação
#
# *Moacir Antonelli Ponti*<br>
# *ICMC/USP São Carlos*

# %% [markdown]
# <font color='red'> As respostas devem ser fornecidas no Moodle. O notebook é apenas para a implementação dos códigos que fornecerão as respostas</font>
#
# <font color='red'> _This notebook should be used to implement the source-code in order to obtain the results. With those results, answer the questions in the Moodle system._ </font>

# %% [markdown]
# ## Questão 1
#
# Considere a estrutura abaixo que contém notas de turmas de dois cursos (Python e Redes Neurais), para diferentes anos. Calcule e armazene a média das notas da turma de Python em 2020, e da turma de Redes Neurais, também em 2020. Qual é a diferença absoluta entre essas médias, considerando 3 casas decimais?
#
# a) 0.500<br>
# b) 0.667<br>
# c) 0.333<br>
# d) 0.700

# %%
notas = {
    'Python': { '2020': [[9.5, 8.0, 10.0, 5.0, 6.0, 6.0]],
                2021: [[8.2, 10.0, 10.0, 9.0, 7.5, 7.0, 10.0]] },
    'Redes Neurais': {  2018: [[1.0, 7.8, 7.0, 5.0, 9.2, 7.0, 6.5]],
                        2019: [[8.0, 9.8, 10.0, 0.0, 8.2, 7.5, 7.5]],
                       2020: [[9.0, 7.2, 9.0, 8.0, 6.3, 7.0]],
                       2021: [[10.0, 7.5, 8.0, 9.0, 7.0, 7.3, 6.5]] }
}

# %% [markdown]
# ## Questão 2
#
# Crie e armazene uma primeira lista `quads` contendo os quadrados dos números `x`, isso é `x**2`, no intervalo entre -25 e 25 (inclusive). A seguir, crie e armazene uma segunda lista `cubos` contendo o valor absoluto dos números `x` ao cubo, isso é `abs(x**3)`, no intervalo entre -10 e 10 (inclusive), mas apenas para os valores de `x` que não façam parte dos elementos da lista `quads`.
#
# Quantos elementos possui a lista `cubos`?
#
# a) 4<br>
# b) 21<br>
# c) 19<br>
# d) 17<br>

# %% [markdown]
# ## Questão 3
#
# Crie uma função lambda que processe uma tupla contendo um produto definido na forma:
# (nome_produto (str), preco (float), ano validade (int), mes validade (int))
# E que retorne uma nova tupla contendo o nome do produto concatenado com ` em promoção`, e o preço com desconto de 50%.
#
# Exemplo: `('macarrao', 10.0, 2021, 8)`
#
# Saída da função: `('macarrao em promocao', 5.0, 2021, 8)`
#
# Crie uma função que receba uma lista contendo as tuplas de produtos, um ano e mês de vencimento, e que utilize essa função lambda numa comprehension para retornar uma nova lista contendo apenas produtos próximos ao vencimento, para os quais será feita uma promoção com desconto de 50%. Serão considerados próximos ao vencimento produtos até o ano e mês passados como argumento da função.
#
# Exemplo de uso da funcao: gera_lista_promocao(prods, 2021, 8).
#
# Considerando que produtos com vencimento até Agosto de 2021 estão próximos ao vencimento, use sua função para retornar uma lista de produtos em promoção. Qual é o preço mínimo e máximo dos produtos dessa lista?
#
# a) Menor: 1,00; Maior: 4,49<br>
# b) Menor: 1,25; Maior: 5,25<br>
# c) Menor: 1,25; Maior: 4,49<br>
# d) Menor: 1,00; Maior: 5,25

# %%
prods = [('macarrao', 5.99, 2021, 7),
      ('palmito', 12.50, 2022, 8),
      ('arroz', 21.50, 2021, 9),      
      ('feijao', 8.50, 2022, 10),
      ('grao de bico', 8.50, 2022, 8),
      ('feijao preto', 8.90, 2021, 7),
      ('molho', 2.50, 2021, 6),
      ('cafe', 7.30, 2021, 6),
      ('manteiga', 8.99, 2021, 7),
      ('chocolate', 2.00, 2021, 9),
      ('azeite', 10.50, 2022, 1),
      ('farinha', 3.50, 2021, 7),
      ('fuba', 4.50, 2022, 8)]

# %% [markdown]
# ## Questão 4
#
# Defina a semente do pacote random do numpy como 1. Depois, gere um array com 72 elementos inteiros aleatórios entre 1 e 50 (usando `numpy.random.randint`) e altere o formato do array para uma matriz de 6 x 12 elementos. A seguir, extraia a submatriz relativa às linhas de 2 até 4 (inclusive), e as últimas 4 colunas.
#
# Nessa submatriz resultante, utilize um método de redução para obter o índice dos maiores elementos em cada uma das suas linhas. Quais são esses índices?
#
# a) [1, 0]<br>
# b) [1, 0, 3]<br>
# c) [1, 0, 2, 2]<br>
# d) [1, 0, 2]<br>

# %%
import numpy as np
np.random.seed(1)
# seu código

# %% [markdown]
# ## Questão 5
#
# Carregue o arquivo `sales2.csv`. Sem realizar nenhum pré processamento
#
# 1. Crie uma visão do dataframe contendo as colunas Item Type e Total Profit apenas das linhas com Order Priority = H, e com Units Sold maior do que 1000.
# 2. Nessa visão, calcule a média e o máximo do Total Profit agrupado pelo Item Type.
#
# Quais são os valores de média e máximo para os itens de tipo: Beverages e Vegetables, sem considerar casas decimais?
#
# a) Beverages: Média=111837, Máximo=147031; Fruits: Média=9485, Máximo 18405<br>
# b) Beverages: Média=147031, Máximo=147031; Fruits: Média=12228, Máximo 18405<br>
# c) Beverages: Média=111837, Máximo=111837; Fruits: Média=9485, Máximo 12228<br>
# d) Beverages: Média=147031, Máximo=147031; Fruits: Média=9485, Máximo 18405<br>

# %%
import pandas as pd
df = pd.read_csv('sales2.csv')
